# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8be676bc-11c1-4ec3-9735-2a3f12345d07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8be676bc-11c1-4ec3-9735-2a3f12345d07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'archive.zip', 'sample_data']

# %%
import zipfile

zip_file = "archive.zip"

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall("rainfall_data")

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

for root, dirs, files in os.walk("rainfall_data"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# rainfall_data/daily-rainfall-at-state-level.csv

# %%
import pandas as pd

rainfall = pd.read_csv("rainfall_data/daily-rainfall-at-state-level.csv")

display(rainfall.head())
# Out:
#    id        date  state_code        state_name  actual       rfs  normal  \
# 0   0  2009-01-01           5       Uttarakhand     0.0  0.003906    2.19
# 1   1  2009-01-01          18             Assam     0.0  0.000000    0.52
# 2   2  2009-01-01          16           Tripura     0.0  0.000000    0.09
# 3   3  2009-01-01          36         Telangana     0.0  0.000000    0.17
# 4   4  2009-01-01           2  Himachal Pradesh     0.0  0.008566    3.31
#
#    deviation
# 0     -100.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4     -100.0

# %%
print("Rows and columns:", rainfall.shape)
print("\nColumns:")
print(rainfall.columns.tolist())
# Out:
# Rows and columns: (204876, 8)
#
# Columns:
# ['id', 'date', 'state_code', 'state_name', 'actual', 'rfs', 'normal', 'deviation']

# %%
rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204876 entries, 0 to 204875
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          204876 non-null  int64
#  1   date        204876 non-null  object
#  2   state_code  204876 non-null  int64
#  3   state_name  204876 non-null  object
#  4   actual      187714 non-null  float64
#  5   rfs         199011 non-null  float64
#  6   normal      193358 non-null  float64
#  7   deviation   173855 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 12.5+ MB

# %%
print(rainfall.shape)
print(rainfall.columns.tolist())
display(rainfall.head())
# Out:
# (204876, 8)
# ['id', 'date', 'state_code', 'state_name', 'actual', 'rfs', 'normal', 'deviation']
#    id        date  state_code        state_name  actual       rfs  normal  \
# 0   0  2009-01-01           5       Uttarakhand     0.0  0.003906    2.19
# 1   1  2009-01-01          18             Assam     0.0  0.000000    0.52
# 2   2  2009-01-01          16           Tripura     0.0  0.000000    0.09
# 3   3  2009-01-01          36         Telangana     0.0  0.000000    0.17
# 4   4  2009-01-01           2  Himachal Pradesh     0.0  0.008566    3.31
#
#    deviation
# 0     -100.0
# 1     -100.0
# 2     -100.0
# 3     -100.0
# 4     -100.0

# %%
rainfall.to_csv(
    "/content/rainfall_data.csv",
    index=False
)

print("Rainfall dataset saved!")
# Out:
# Rainfall dataset saved!

# %%
import os

print(os.path.getsize("/content/rainfall_data.csv") / (1024 * 1024), "MB")
# Out:
# 10.47753620147705 MB
